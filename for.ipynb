# %%
age=int(input("Enter the age: "))
list=[23,45,67,34,89]
for age in list:
    if(age<18):
        print("children")
    elif(age<35):
        print("Adult")
    elif(age<59):
        print("citizen")
    else:
        print("senior citizens")
# Out:
# Enter the age:  45
# Adult
# citizen
# senior citizens
# Adult
# senior citizens
