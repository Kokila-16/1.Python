# %%
from AllFunctions import multiplefunctions

# %%
multiplefunctions.subfields()
# Out:
# machine learning
# neural networks
# vision
# robotics
# speech processing
# natural language processing

# %%
multiplefunctions.oddeven()
# Out:
# Enter a number: 9
# It is odd number
# 'odd Number'

# %%
multiplefunctions.marelig()
# Out:
# Your gender: female
# Your age: 26
# It is eligible
# 'It is eligible'

# %%
multiplefunctions.percentage(98,87,95,95,93)
# Out:
# Total: 468
# Percentage 93.6

# %%
multiplefunctions.triangle()
# Out:
# The Area of Triangle
# Enter the height: 5
# Enter the breadth: 8
# The Area of Triangle is 20.0
# The perimeter of Triangle
# Enter the height1: 9
# Enter the height2: 7
# Enter the breadth: 5
# The perimeter of Triangle is 21
