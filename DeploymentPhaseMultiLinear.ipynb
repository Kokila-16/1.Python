# %%
import pickle

# %%
loaded_model=pickle.load(open("finalised_model_mul_linear.sav",'rb'))
result=loaded_model.predict([[1234,345,4565,1,0]])
# Out:
# C:\Anaconda 3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[43994.79745873]])
